# %%
import plotly.express as px



df = px.data.gapminder()
fig = px.area(df, x="year", y="pop", color="continent", line_group="country")

df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
import pandas as pd

import matplotlib.pyplot as plt

games_df = pd.read_csv('games.csv')
games_df = games_df.loc[(games_df['Year_of_Release']>=2000)].dropna()

#games_df

dff = pd.DataFrame(games_df.groupby('Platform')['Year_of_Release'].value_counts()).rename(columns={'Year_of_Release':'Volume'}).reset_index().rename(columns={'Year_of_Release':'Year of Release'}).sort_values(by='Year of Release')

# %%
merged_df = games_df.merge(dff, left_on=['Platform','Year_of_Release'], right_on=['Platform','Year of Release']).head(60)

# %%
platform_year_df = pd.DataFrame(games_df.groupby('Platform')['Year_of_Release'].value_counts()).\
    rename(columns={'Year_of_Release':'Volume'}).reset_index().rename(columns={'Year_of_Release':'Year of Release'})

# %%
games_df.groupby(["Platform", "Year_of_Release"]).size().reset_index(name="Volume")
# Out:
#     Platform  Year_of_Release  Volume
# 0        3DS           2011.0      61
# 1        3DS           2012.0      33
# 2        3DS           2013.0      20
# 3        3DS           2014.0      22
# 4        3DS           2015.0      19
# ..       ...              ...     ...
# 120       XB           2007.0       3
# 121     XOne           2013.0      14
# 122     XOne           2014.0      43
# 123     XOne           2015.0      47
# 124     XOne           2016.0      57
#
# [125 rows x 3 columns]

# %%
# platform_year_df = games_df.merge(games_df.groupby(["Platform", "Year_of_Release"]).size().reset_index(name="Volume"),\
#                                   left_on=['Platform','Year_of_Release'], right_on=['Platform','Year_of_Release'])

games_df.loc[games_df['Genre'].isin(['']) | games_df['Rating'].isin(['E','T'])]
# Out:
#                                           Name Platform  Year_of_Release  \
# 0                                   Wii Sports      Wii           2006.0
# 2                               Mario Kart Wii      Wii           2008.0
# 3                            Wii Sports Resort      Wii           2009.0
# 6                        New Super Mario Bros.       DS           2006.0
# 7                                     Wii Play      Wii           2006.0
# ...                                        ...      ...              ...
# 16673  Super Robot Taisen: Original Generation      GBA           2002.0
# 16699                          Planet Monsters      GBA           2001.0
# 16700                                   Breach       PC           2011.0
# 16701                         Bust-A-Move 3000       GC           2003.0
# 16702                         Mega Brain Boost       DS           2008.0
#
#               Genre  Critic_Score User_Score Rating
# ...

# %%
games_df['Year_of_Release'].max().astype(int)
# Out:
# 2016
