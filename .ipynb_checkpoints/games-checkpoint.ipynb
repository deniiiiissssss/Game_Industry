# %%
import pandas as pd

import matplotlib.pyplot as plt


games_df = pd.read_csv('games.csv')
games_df = games_df.loc[(games_df['Year_of_Release']>=2000)].dropna()
#games_df.loc[games_df['Genre'].isin(['Sports']) & games_df['Rating'].isin(['E'])]

# %%
g=games_df.groupby(['Name','Year_of_Release']).agg(['count'])
gff = g.where(g>1).dropna().reset_index()
gff.loc[gff['Name']=='Grand Theft Auto V']
# Out:
#                    Name Year_of_Release Platform Genre Critic_Score  \
#                                            count count        count
# 477  Grand Theft Auto V          2013.0      2.0   2.0          2.0
# 478  Grand Theft Auto V          2014.0      2.0   2.0          2.0
#
#     User_Score Rating
#          count  count
# 477        2.0    2.0
# 478        2.0    2.0

# %%
print(games_df.Genre.value_counts(),'\n',games_df.Rating.value_counts())
# Out:
# Action          1821
# Sports          1144
# Shooter          912
# Role-Playing     707
# Racing           706
# Misc             502
# Platform         483
# Fighting         394
# Simulation       335
# Adventure        295
# Strategy         279
# Puzzle           214
# Name: Genre, dtype: int64
#  E       2709
# T       2543
# M       1443
# E10+    1095
# AO         1
# RP         1
# Name: Rating, dtype: int64

# %%
games_df.loc[(games_df.Genre.isin(list(['Racing']))) & (games_df.Rating.isin(list(['T'])))]
# Out:
#                                Name Platform  Year_of_Release   Genre  \
# 253     Need for Speed: Most Wanted      PS2           2005.0  Racing
# 317                      MotorStorm      PS3           2006.0  Racing
# 355         The Simpsons: Road Rage      PS2           2001.0  Racing
# 562             Burnout 3: Takedown      PS2           2004.0  Racing
# 579    Midnight Club: Street Racing      PS2           2000.0  Racing
# ...                             ...      ...              ...     ...
# 15834           Top Gear RPM Tuning       XB           2005.0  Racing
# 16242               Furious Karting       XB           2003.0  Racing
# 16421     FlatOut: Ultimate Carnage       PC           2008.0  Racing
# 16459                    Powerdrome       XB           2004.0  Racing
# 16488   Juiced 2: Hot Import Nights       PC           2007.0  Racing
#
#        Critic_Score User_Score Rating
# 253            82.0        9.1      T
# 317            84.0        7.4      T
# 355            64.0        7.7      T
# 562            93.0        9.1      T
# 579            78.0        7.8      T
# ...             ...        ...    ...
# 15834          45.0        7.5      T
# 16242          63.0        tbd      T
# 16421          79.0        7.7      T
# 16459          69.0          7      T
# 16488          61.0          5      T
#
# [160 rows x 7 columns]

# %%
games_df.loc[games_df.Rating.isin(list([games_df.Rating.unique()])) | games_df.Genre.isin(list(['Sports','Action']))]
# Out:
#                                           Name Platform  Year_of_Release  \
# 0                                   Wii Sports      Wii           2006.0
# 2                               Mario Kart Wii      Wii           2008.0
# 3                            Wii Sports Resort      Wii           2009.0
# 6                        New Super Mario Bros.       DS           2006.0
# 7                                     Wii Play      Wii           2006.0
# ...                                        ...      ...              ...
# 16673  Super Robot Taisen: Original Generation      GBA           2002.0
# 16699                          Planet Monsters      GBA           2001.0
# 16700                                   Breach       PC           2011.0
# 16701                         Bust-A-Move 3000       GC           2003.0
# 16702                         Mega Brain Boost       DS           2008.0
#
#               Genre  Critic_Score User_Score Rating
# 0            Sports          76.0          8      E
# 2            Racing          82.0        8.3      E
# 3            Sports          80.0          8      E
# 6          Platform          89.0        8.5      E
# 7              Misc          58.0        6.6      E
# ...             ...           ...        ...    ...
# 16673  Role-Playing          72.0        tbd      T
# 16699        Action          67.0        tbd      E
# 16700       Shooter          61.0        5.8      T
# 16701        Puzzle          53.0        tbd      E
# 16702        Puzzle          48.0        tbd      E
#
# [5252 rows x 7 columns]
