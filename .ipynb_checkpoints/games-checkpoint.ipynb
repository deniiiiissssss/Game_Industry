# %%
import pandas as pd
import plotly.express as px

# MAIN DATAFRAME
games_df = pd.read_csv('games.csv')
games_df = games_df.loc[(games_df['Year_of_Release'] >= 2000)].dropna()
games_df['Year_of_Release'] = games_df['Year_of_Release'].astype(int)

#cn_df = len(games_df.loc[(games_df.Rating.isin(list(rating_dropdown))) | (games_df.Genre.isin(list(genre_dropdown)))])

# %%
genre_dropdown = ['Sports']
rating_dropdown = ['E10+']
games_df.loc[(games_df.Rating.isin(rating_dropdown)) & (games_df.Genre.isin(list(genre_dropdown)))]
# Out:
#                                Name Platform  Year_of_Release     Genre  \
# 0                        Wii Sports      Wii             2006    Sports
# 3                 Wii Sports Resort      Wii             2009    Sports
# 13                          Wii Fit      Wii             2007    Sports
# 15                     Wii Fit Plus      Wii             2009    Sports
# 61                     Just Dance 3      Wii             2011      Misc
# ...                             ...      ...              ...       ...
# 16550   Wade Hixton's Counter Punch      GBA             2004    Sports
# 16573  The Eye of Judgment: Legends      PSP             2010  Strategy
# 16624                         Trine       PC             2009    Action
# 16644               Hospital Tycoon       PC             2007  Strategy
# 16706       STORM: Frontline Nation       PC             2011  Strategy
#
#        Critic_Score User_Score Rating
# 0              76.0          8      E
# 3              80.0          8      E
# 13             80.0        7.7      E
# 15             80.0        7.4      E
# 61             74.0        7.8   E10+
# ...             ...        ...    ...
# 16550          78.0        9.5      T
# 16573          69.0        7.9   E10+
# 16624          80.0        8.2   E10+
# 16644          51.0        3.8   E10+
# 16706          60.0        7.2   E10+
#
# [2149 rows x 7 columns]
